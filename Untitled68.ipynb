// %%
import asyncio
import ccxt.async_support as ccxt
import pandas as pd
import numpy as np
import pandas_ta as ta
from textblob import TextBlob
import logging
import json
import sys
import os

# Load configuration
with open("config.json") as config_file:
    config = json.load(config_file)

logging.basicConfig(filename='trading_bot.log', level=logging.INFO, format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p')

# Initialize Binance API
exchange = ccxt.binance({
    "apiKey": config["api_key"],
    "secret": config["api_secret"]
})

def calculate_technical_indicators(data, short_ma, long_ma):
    data['short_ma'] = ta.ema(data['close'], length=short_ma)
    data['long_ma'] = ta.ema(data['close'], length=long_ma)
    return data

async def fetch_historical_data(symbol, limit):
    data = await exchange.fetch_ohlcv(symbol, timeframe='1m', limit=limit)
    df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    return df

def generate_signals(data):
    signals = {}
    signals["long"] = data["short_ma"].iloc[-1] > data["long_ma"].iloc[-1] and data["short_ma"].iloc[-2] <= data["long_ma"].iloc[-2]
    signals["short"] = data["short_ma"].iloc[-1] < data["long_ma"].iloc[-1] and data["short_ma"].iloc[-2] >= data["long_ma"].iloc[-2]
    return signals

def sentiment_analysis(data):
    blob = TextBlob(str(data))
    return blob.sentiment.polarity

async def get_balance(symbol):
    balance = await exchange.fetch_balance()
    return balance[symbol]

async def place_order(order_type, symbol, trade_amount, stop_loss_percentage, take_profit_percentage):
    if order_type == "buy":
        side = "buy"
    elif order_type == "sell":
        side = "sell"
    else:
        raise ValueError("Invalid order type")

    order = await exchange.create_market_order(symbol, side, trade_amount)
    price = order["price"]

    stop_loss_price = price * (1 - stop_loss_percentage) if order_type == "buy" else price * (1 + stop_loss_percentage)
    take_profit_price = price * (1 + take_profit_percentage) if order_type == "buy" else price * (1 - take_profit_percentage)

    stop_loss_order = await exchange.create_order(symbol, "stop_loss", side, trade_amount, stop_loss_price)
    take_profit_order = await exchange.create_order(symbol, "take_profit", side, trade_amount, take_profit_price)

    return order, stop_loss_order, take_profit_order

async def main():
    logging.info("Starting trading bot")

    symbol = config["symbol"]
    limit = config["limit"]

    try:
        data = await fetch_historical_data(symbol, limit)
        data = calculate_technical_indicators(data, 12, 26)

        signals = generate_signals(data)

        sentiment = sentiment_analysis(data)

        balance = await get_balance("BTC")
        trade_amount = balance * 0.1  # Adjust this value based on your desired position size
                stop_loss_percentage = 0.03  # Adjust this value based on your risk tolerance
        take_profit_percentage = 0.06  # Adjust this value based on your desired profit target

        if signals["long"] and sentiment > 0:
            logging.info("Placing a long order")
            order, stop_loss_order, take_profit_order = await place_order("buy", symbol, trade_amount, stop_loss_percentage, take_profit_percentage)
            logging.info(f"Long order placed: {order}, Stop loss: {stop_loss_order}, Take profit: {take_profit_order}")
        elif signals["short"] and sentiment < 0:
            logging.info("Placing a short order")
            order, stop_loss_order, take_profit_order = await place_order("sell", symbol, trade_amount, stop_loss_percentage, take_profit_percentage)
            logging.info(f"Short order placed: {order}, Stop loss: {stop_loss_order}, Take profit: {take_profit_order}")

    except Exception as e:
        logging.error(f"An error occurred: {e}")
        sys.exit(1)

    logging.info("Trading bot finished successfully")

if __name__ == "__main__":
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())
// Out:
// SyntaxError: unknown: Unexpected token, expected "from" (2:0)
//
//   1 | import asyncio
// > 2 | import ccxt.async_support as ccxt
//     | ^
//   3 | import pandas as pd
//   4 | import numpy as np
//   5 | import pandas_ta as ta
//     at instantiate (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:653:32)
//     at constructor (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:947:12)
//     at Parser.raise (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:3261:19)
//     at Parser.unexpected (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:3291:16)
//     at Parser.expectContextual (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:3610:12)
//     at Parser.parseImport (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:14044:12)
//     at Parser.parseStatementContent (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:12651:27)
//     at Parser.parseStatementLike (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:12544:17)
//     at Parser.parseModuleItem (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:12521:17)
//     at Parser.parseBlockOrModuleBlockBody (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:13116:36)
//     at Parser.parseBlockBody (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:13109:10)
//     at Parser.parseProgram (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:12435:10)
//     at Parser.parseTopLevel (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:12425:25)
//     at Parser.parse (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:14245:10)
//     at parse (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\parser\lib\index.js:14286:38)
//     at parser (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\core\lib\parser\index.js:41:34)
//     at parser.next (<anonymous>)
//     at normalizeFile (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\core\lib\transformation\normalize-file.js:64:38)
//     at normalizeFile.next (<anonymous>)
//     at run (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\core\lib\transformation\index.js:21:50)
//     at run.next (<anonymous>)
//     at transform (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\core\lib\transform.js:22:41)
//     at transform.next (<anonymous>)
//     at evaluateSync (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\gensync\index.js:251:28)
//     at sync (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\gensync\index.js:89:14)
//     at stopHiding - secret - don't use this - v1 (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\core\lib\errors\rewrite-stack-trace.js:46:12)
//     at transform (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\@babel\core\lib\transform.js:36:80)
//     at Session.transpile (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\lib\kernel.js:129:26)
//     at Session._runNow (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\nel\lib\nel.js:835:39)
//     at Session._run (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\nel\lib\nel.js:786:14)
//     at Session.execute (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\nel\lib\nel.js:929:10)
//     at Kernel.execute_request (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\jp-kernel\lib\handlers_v5.js:116:18)
//     at Kernel.onShellMessage (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\jp-kernel\lib\jp-kernel.js:285:41)
//     at Socket.<anonymous> (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\jmp\index.js:350:17)
//     at Socket.emit (node:events:512:28)
//     at Socket._emitMessage (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\zeromq\lib\index.js:649:15)
//     at Socket._flushRead (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\zeromq\lib\index.js:660:10)
//     at Socket._flushReads (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\zeromq\lib\index.js:696:15)
//     at Immediate._onImmediate (C:\Users\Brier\AppData\Roaming\npm\node_modules\jp-babel\node_modules\zeromq\lib\index.js:307:12)
//     at process.processImmediate (node:internal/timers:478:21)
