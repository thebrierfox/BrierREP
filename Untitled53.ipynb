# %%
import requests
from bs4 import BeautifulSoup
import csv

# Send a GET request to the webpage
url = "https://www.dividend.com/best-high-dividend-stocks/"
response = requests.get(url)

# Parse the HTML response using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Print the soup variable to see the HTML structure
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link href="https://www.dividend.com/feed/" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <script>
#    window.websiteProperty = "dividend"; window.MPageTargets = JSON.parse('{}');
#   window.tagList = JSON.parse("[&quot;Evergreen Article&quot;]".replace(/&quot;/g, '\"'));
#   window.MConstants = JSON.parse('{"cachedSecurities":[{"symbol":"SEEGX","security_type":"funds","data":{"symbol":"SEEGX","share_class":"Inst","price_as_of":"2022-12-22","price_change_percent":-1.606,"dividend_yield_current":0.004012969588550984,"index_fund":false,"dividend_annual_current":0.17946,"net_assets":"33333720341","trailing_yield":0.004,"expense_ratio":"0.69","exchange":null,"ltm_dividend":0.17946,"legal_name":"JPMorgan Large Cap Growth Fund","security_type":"mutual_fund","last_price":44.72,"intraday_price":null,"changes":0,"watchlist_state":"false"},"id":96,"created_at":"2021-06-15T11:41:19.000-04:00","updated_at":"2022-12-25T06:33:06.000-05:00","location":"sr"},{"symbol":"JQUA","security_type":"funds","data":{"symbol":"JQUA","share_class":null,"price_as_of":"2023-03-10","price_change_percent":-1.444134785913352,"dividend_yield_current":0.020615938303341904,"index_fund":true,"dividend_annual_current":0.80196,"net_assets":"381596457","trailing_yield":0.0159,"expense_ratio":"0.12","exchange":"ARCX","ltm_dividend":0.61822,"legal_name":"JPMorgan U.S. Quality Factor ETF","security_type":"etf","last_price":38.9,"intraday_price":null,"changes":0,"watchlist_state":"false"},"id":97,"created_at":"2021-06-15T11:41:26.000-04:00","updated_at":"2023-03-11T06:46:59.000-05:00","location":"sr"},{"symbol":"JMSIX","security_type":"funds","data":{"symbol":"JMSIX","share_class":"Inst","price_as_of":"2023-03-10","price_change_percent":0.0,"dividend_yield_current":0.05368750048543689,"index_fund":false,"dividend_annual_current":0.44238500399999997,"net_assets":"10983204090","trailing_yield":0.0413,"expense_ratio":"0.41","exchange":null,"ltm_dividend":0.340207443,"legal_name":"JPMorgan Income Fund","security_type":"mutual_fund","last_price":8.24,"intraday_price":null,"changes":0,"watchlist_state":"false"},"id":98,"created_at":"2021-06-15T11:41:37.000-04:00","updated_at":"2023-03-12T03:47:36.000-04:00","location":"sr"},{"symbol":"JEPI","security_type":"funds","data":{"symbol":"JEPI","share_class":null,"price_as_of":"2023-03-10","price_change_percent":-1.3436790310370932,"dividend_yield_current":0.094644158833685,"index_fund":false,"dividend_annual_current":4.9338,"net_assets":"9828919216","trailing_yield":0.1223,"expense_ratio":"0.35","exchange":"ARCX","ltm_dividend":6.37314,"legal_name":"JPMorgan Equity Premium Income ETF","security_type":"etf","last_price":52.13,"intraday_price":null,"changes":0,"watchlist_state":"false"},"id":99,"created_at":"2021-06-15T11:41:44.000-04:00","updated_at":"2023-03-11T06:46:59.000-05:00","location":"sr"},{"symbol":"JEPIX","security_type":"funds","data":{"symbol":"JEPIX","share_class":"Inst","price_as_of":"2023-03-10","price_change_percent":-1.215,"dividend_yield_current":0.09916082490392006,"index_fund":false,"dividend_annual_current":1.2900823319999999,"net_assets":"3492365357","trailing_yield":0.1286,"expense_ratio":"0.61","exchange":null,"ltm_dividend":1.672660212,"legal_name":"JPMorgan Equity Premium Income Fund","security_type":"mutual_fund","last_price":13.01,"intraday_price":null,"changes":0,"watchlist_state":"false"},"id":108,"created_at":"2021-10-31T20:25:41.000-04:00","updated_at":"2023-03-13T04:48:15.000-04:00","location":"sr"},{"symbol":"IUESX","security_type":"funds","data":{"symbol":"IUESX","share_class":"Inst","price_as_of":"2023-03-10","price_change_percent":-0.674,"dividend_yield_current":0.03536347197106691,"index_fund":false,"dividend_annual_current":0.78224,"net_assets":"1399501404","trailing_yield":0.0354,"expense_ratio":"0.75","exchange":null,"ltm_dividend":0.78224,"legal_name":"JPMorgan International Focus Fund","security_type":"mutual_fund","last_price":22.12,"intraday_price":null,"changes":0,"watchlist_state":"false"},"id":109,"created_at":"2021-10-31T20:26:26.000-04:00","updated_at":"2023-03-13T03:48:12.000-04:00","location":"sr"},{"symbol":"SRBFX","security_type":"funds","data":{"symbol":"SRBFX","share_class":"Inst","price_as_of":"2023-03-10","price_change_percent":1.171,"dividend_ ...
#   window.serverEnv = "production"
#   </script>
#   <script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <link href="/packs/css/dividend/home-application-92b78752.css" media="screen" rel="stylesheet"/>
#   <script src="/packs/js/dividend/table-application-34a47bc027f3fc471f62.js">
#   </script>
#   <title>
#    Best High Yield - Dividend.com
#   </title>
#   <meta content="Targeting a high dividend yield of 7-9%. Updated daily, only the very best make it through the industry’s strictest high dividend screening test and manual selection process. Given the rising interest rates, we've heard the calls for more yield. If inflat" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta property="og:description"/>
#   <meta content="Dividend.com" property="og:site_name"/>
#   <meta content="https://www.dividend.com/packs/media/images/dividend/dividend-logo-e3b941f3773f8159bf1ba862ffafe4a7.svg" property="og:image"/>
#   <meta content="Dividend.com" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Dividend.com" property="og:url"/>
#   <meta name="twitter:description"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Dividend.com" name="twitter:domain"/>
#   <meta content="https://www.dividend.com/packs/media/images/dividend/dividend-logo-e3b941f3773f8159bf1ba862ffafe4a7.svg" name="twitter:image:src"/>
#   <meta content="Dividend.com" name="twitter:site"/>
#   <meta content="Dividend.com" name="twitter:title"/>
#   <link href="/packs/media/images/dividend/favicon-06e5f2ac9e42a6a46cc8e04e4e1d1e50.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/packs/media/images/dividend/apple-touch-icon-b5ffc95121f1b9acf235c0c054abfc2b.png" rel="apple-touch-icon" type="image/png"/>
#   <link href="/packs/media/images/dividend/apple-touch-icon-precomposed-b5ffc95121f1b9acf235c0c054abfc2b.png" rel="apple-touch-icon-precomposed" type="image/png"/>
#   <link href="/packs/media/images/dividend/apple-touch-icon-76x76-48b64f155bbba75f1fb9e807a70f7fb6.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
#   <link href="/packs/media/images/dividend/apple-touch-icon-120x120-dc3147bf6f3978d033fabdeac3c93197.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
#   <link href="/packs/media/images/dividend/apple-touch-icon-152x152-23e1b4daba6daf6ff97246e9e3bf747d.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
#   <meta content="authenticity_token" name="csrf-param">
#    <meta content="Kl2zmekj9kXGNwH5xM88FT9XZTpsuQGKYXCNEveafPiFlyvhu7/ACQs4CB6JiGwpIk0z3v+O/f9wnz2gGe1fIw==" name="csrf-token">
#     <div class="async-js" data-js-files="[]">
#     </div>
#    </meta>
#   </meta>
#  </head>
#  <body class="t-font-inter n-body" data-controller="setup">
#   <div id="alert-container">
#    <div id="alert-dom">
#    </div>
#   </div>
#   <div class="async-js" data-js-files="[]">
#   </div>
#   <header class="n-header__mobile sticky-element t-bg-white t-shadow t-sticky t-w-full t-z-40 xl:t-hidden" data-homepage-nav-target="navBar">
#    <div id="mobile-only-header">
#     <div class="t-flex t-items-center t-p-3">
#      <div class="t-flex-none">
#       <button class="t-py-1 t-px-2" id="mobile-nav-reference">
#        <svg height="13px" version="1.1" viewbox="0 0 18 13" width="18px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <g fill="none" fill-rule="evenodd" id="Nav" stroke="none" stroke-width="1">
#          <g fill="#000000" id="When-the-screen-is-scrolled" transform="translate(-29.000000, -63.000000)">
#           <g id="Group-6" transform="translate(29.000000, 63.000000)">
#            <rect height="1" id="Rectangle" rx="0.5" width="18" x="0" y="0">
#            </rect>
#            <rect height="1" id="Rectangle-Copy-4" rx="0.5" width="18" x="0" y="6">
#            </rect>
#            <rect height="1" id="Rectangle-Copy-5" rx="0.5" width="18" x="0" y="12">
#            </rect>
#           </g>
#          </g>
#         </g>
#        </svg>
#       </button>
#      </div>
#      <div class="t-flex-1">
#       <figure class="t-m-0 t-flex t-justify-center">
#        <a href="/">
#         <img class="t-h-6" data-homepage-nav-target="homepageLogoColor" src="/packs/media/images/dividend/dividend-logo-e3b941f3773f8159bf1ba862ffafe4a7.svg"/>
#         <img class="t-h-6 t-hidden" data-homepage-nav-target="homepageLogoWhite" src="/packs/media/images/dividend/dividend-logo-white-7f125ae49fb8be9e28935ae01fdbd716.png"/>
#        </a>
#       </figure>
#      </div>
#      <div class="t-flex-none">
#       <div class="n-nav-button t-flex t-items-center t-border-white t-relative t-mx-2" data-component-render-url="/api/components/full-screen-search/" data-controller="analytics component-render">
#        <a class="t-cursor-pointer nav-full-screen-search" data-action="click-&gt;analytics#dispatchGA click-&gt;component-render#show" data-analytics="W3sic2hvcnRjb2RlIjoiSFNDSVZTQyJ9XQ==
# ">
#         <svg class="t-pointer-events-none" height="17px" version="1.1" viewbox="0 0 17 17" width="17px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#          <g fill="none" fill-rule="evenodd" id="Nav" stroke="none" stroke-width="1">
#           <g id="Nav---Channel-dropdown" stroke="#000000" transform="translate(-1083.000000, -62.000000)">
#            <g id="Group" transform="translate(1092.000000, 71.500000) rotate(-45.000000) translate(-1092.000000, -71.500000) translate(1085.000000, 61.000000)">
#             <circle cx="7.37867966" cy="6.79289322" id="Oval" r="6">
#             </circle>
#             <path d="M7.73223305,12.7388348 L7.73223305,19.9388348" id="Line-2" stroke-linecap="round">
#             </path>
#            </g>
#           </g>
#          </g>
#         </svg>
#        </a>
#        <div class="n-nav-bottom-bar">
#        </div>
#       </div>
#       <div class="async-js" data-js-files="[]">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="t-hidden" id="desktop-only-header-container">
#    </div>
#   </header>
#   <div class="mitread--adunit__fpa ad-type-FP-01-A t-flex t-justify-center t-items-center t-my-1" id="f6f913e98ce56d6ddfb669e5f99c0cde-c">
#    <div data-ad-unit-ad-unit="FP-01-A" data-ad-unit-id="f6f913e98ce56d6ddfb669e5f99c0cde" data-ad-unit-is-native="true" data-ad-unit-kfp="true" data-ad-unit-name="Div/Theme/BestList/FP-01-A" data-ad-unit-type="fpa" data-controller="ad-unit" id="f6f913e98ce56d6ddfb669e5f99c0cde">
#    </div>
#    <div data-ad-position-id="/2143012/Div/Theme/BestList/FP-01-A" data-controller="ad-position">
#    </div>
#   </div>
#   <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#   </div>
#   <section class="n-nav__mobile t-bg-white t-hidden">
#    <div id="mobile-user-data-area">
#    </div>
#    <div class="n-nav-item__mobile" id="nav-item-home">
#     <div class="t-flex">
#      <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/" href="/">
#       Home
#      </a>
#     </div>
#    </div>
#    <div class="n-nav-item__mobile" id="nav-item-guide">
#     <div class="t-flex">
#      <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-guide">
#       Guide
#       <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#      </div>
#     </div>
#     <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-guide">
#      <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#      </div>
#      <section class="t-bg-white t-flex t-flex-col">
#       <div id="mobile-user-data-area">
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-guide-to-dividend-com">
#        <div class="t-flex">
#         <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-dividends/" href="/best-dividends/">
#          Guide to Dividend.com
#         </a>
#        </div>
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-industry-dividends">
#        <div class="t-flex">
#         <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-industry-dividends">
#          Industry Dividends
#          <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#         </div>
#        </div>
#        <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-industry-dividends">
#         <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#         </div>
#         <section class="t-bg-white t-flex t-flex-col">
#          <div id="mobile-user-data-area">
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-reit">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/reit-industry-dividend-stocks-etfs-and-funds/" href="/reit-industry-dividend-stocks-etfs-and-funds/">
#             REIT
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-mlp">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/mlp-industry-dividend-stocks-etfs-and-funds/" href="/mlp-industry-dividend-stocks-etfs-and-funds/">
#             MLP
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-bdc">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/bdc-dividend-stocks-etfs-and-funds/" href="/bdc-dividend-stocks-etfs-and-funds/">
#             BDC
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-clean-energy">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/renewable-clean-energy-industry-dividend-stocks-etfs-and-funds/" href="/renewable-clean-energy-industry-dividend-stocks-etfs-and-funds/">
#             Clean energy
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-uranium">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/uranium-industry-dividend-stocks-etfs-and-funds/" href="/uranium-industry-dividend-stocks-etfs-and-funds/">
#             Uranium
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-lithium">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/lithium-industry-dividend-stocks-etfs-and-funds/" href="/lithium-industry-dividend-stocks-etfs-and-funds/">
#             Lithium
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-precious-metals">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/precious-metals-sub-industry-dividend-stocks-etfs-and-funds/" href="/precious-metals-sub-industry-dividend-stocks-etfs-and-funds/">
#             Precious metals
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-water">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/water-utilities-industry-dividend-stocks-etfs-and-funds/" href="/water-utilities-industry-dividend-stocks-etfs-and-funds/">
#             Water
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-natural-resources">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/natural-resources-industry-dividend-stocks-etfs-and-funds/" href="/natural-resources-industry-dividend-stocks-etfs-and-funds/">
#             Natural resources
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-energy-infrastructure">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/energy-infrastructure-industry-dividend-stocks-etfs-and-funds/" href="/energy-infrastructure-industry-dividend-stocks-etfs-and-funds/">
#             Energy Infrastructure
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-semiconductors">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/semiconductors-industry-dividend-stocks-etfs-and-funds/" href="/semiconductors-industry-dividend-stocks-etfs-and-funds/">
#             Semiconductors
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-software">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/software-industry-dividend-stocks-etfs-and-funds/" href="/software-industry-dividend-stocks-etfs-and-funds/">
#             Software
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-ecommerce">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/e-commerce-discretionary-sub-industry-dividend-stocks-etfs-and-funds/" href="/e-commerce-discretionary-sub-industry-dividend-stocks-etfs-and-funds/">
#             eCommerce
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-transportation">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/transportation-and-logistics-industry-dividend-stocks-etfs-and-funds/" href="/transportation-and-logistics-industry-dividend-stocks-etfs-and-funds/">
#             Transportation
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-autos">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/automotive-industry-dividend-stocks-etfs-and-funds/" href="/automotive-industry-dividend-stocks-etfs-and-funds/">
#             Autos
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-airlines">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/airlines-sub-industry-dividend-stocks-etfs-and-funds/" href="/airlines-sub-industry-dividend-stocks-etfs-and-funds/">
#             Airlines
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-shipping">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/marine-shipping-sub-industry-dividend-stocks-etfs-and-funds/" href="/marine-shipping-sub-industry-dividend-stocks-etfs-and-funds/">
#             Shipping
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-cruise-lines">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/cruise-lines-sub-industry-dividend-stocks-etfs-and-funds/" href="/cruise-lines-sub-industry-dividend-stocks-etfs-and-funds/">
#             Cruise lines
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-hotels">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/lodging-sub-industry-dividend-stocks-etfs-and-funds/" href="/lodging-sub-industry-dividend-stocks-etfs-and-funds/">
#             Hotels
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-retail">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/retail-industry-dividend-stocks-etfs-and-funds/" href="/retail-industry-dividend-stocks-etfs-and-funds/">
#             Retail
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-iron-steel">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/iron-and-steel-industry-dividend-stocks-etfs-and-funds/" href="/iron-and-steel-industry-dividend-stocks-etfs-and-funds/">
#             Iron &amp; Steel
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-chemicals">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/chemicals-industry-dividend-stocks-etfs-and-funds/" href="/chemicals-industry-dividend-stocks-etfs-and-funds/">
#             Chemicals
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-pharma">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/large-pharma-sub-industry-dividend-stocks-etfs-and-funds/" href="/large-pharma-sub-industry-dividend-stocks-etfs-and-funds/">
#             Pharma
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-insurance">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/insurance-industry-dividend-stocks-etfs-and-funds/" href="/insurance-industry-dividend-stocks-etfs-and-funds/">
#             Insurance
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-aerospace-defense">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/aerospace-and-defense-industry-dividend-stocks-etfs-and-funds/" href="/aerospace-and-defense-industry-dividend-stocks-etfs-and-funds/">
#             Aerospace &amp; Defense
#            </a>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-sector-dividends">
#        <div class="t-flex">
#         <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-sector-dividends">
#          Sector Dividends
#          <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#         </div>
#        </div>
#        <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-sector-dividends">
#         <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#         </div>
#         <section class="t-bg-white t-flex t-flex-col">
#          <div id="mobile-user-data-area">
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-financials">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/financials-sector-dividend-stocks-etfs-and-funds/" href="/financials-sector-dividend-stocks-etfs-and-funds/">
#             Financials
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-real-estate">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/real-estate-sector-dividend-stocks-etfs-and-funds/" href="/real-estate-sector-dividend-stocks-etfs-and-funds/">
#             Real Estate
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-communications">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/communications-sector-dividend-stocks-etfs-and-funds/" href="/communications-sector-dividend-stocks-etfs-and-funds/">
#             Communications
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-consumer-discretionary">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/consumer-discretionary-sector-dividend-stocks-etfs-and-funds/" href="/consumer-discretionary-sector-dividend-stocks-etfs-and-funds/">
#             Consumer Discretionary
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-consumer-staples">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/consumer-staples-sector-dividend-stocks-etfs-and-funds/" href="/consumer-staples-sector-dividend-stocks-etfs-and-funds/">
#             Consumer Staples
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-energy">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/energy-sector-dividend-stocks-etfs-and-funds/" href="/energy-sector-dividend-stocks-etfs-and-funds/">
#             Energy
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-health-care">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/health-care-sector-dividend-stocks-etfs-and-funds/" href="/health-care-sector-dividend-stocks-etfs-and-funds/">
#             Health Care
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-industrials">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/industrials-sector-dividend-stocks-etfs-and-funds/" href="/industrials-sector-dividend-stocks-etfs-and-funds/">
#             Industrials
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-technology">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/technology-sector-dividend-stocks-etfs-and-funds/" href="/technology-sector-dividend-stocks-etfs-and-funds/">
#             Technology
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-materials">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/materials-sector-dividend-stocks-etfs-and-funds/" href="/materials-sector-dividend-stocks-etfs-and-funds/">
#             Materials
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-utilites">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/utilities-sector-dividend-stocks-etfs-and-funds/" href="/utilities-sector-dividend-stocks-etfs-and-funds/">
#             Utilites
#            </a>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-payout-changes">
#        <div class="t-flex">
#         <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-payout-changes">
#          Payout Changes
#          <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#         </div>
#        </div>
#        <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-payout-changes">
#         <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#         </div>
#         <section class="t-bg-white t-flex t-flex-col">
#          <div id="mobile-user-data-area">
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-increasing-dividend">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/stocks-etfs-and-funds-increasing-their-next-dividend/" href="/stocks-etfs-and-funds-increasing-their-next-dividend/">
#             Increasing Dividend
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-decreasing-dividend">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/stocks-etfs-and-funds-decreasing-their-next-dividend/" href="/stocks-etfs-and-funds-decreasing-their-next-dividend/">
#             Decreasing Dividend
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-initiating-dividend">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/stocks-etfs-and-funds-initiating-their-dividend/" href="/stocks-etfs-and-funds-initiating-their-dividend/">
#             Initiating Dividend
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-suspending-dividend">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/stocks-etfs-and-funds-suspending-their-dividend/" href="/stocks-etfs-and-funds-suspending-their-dividend/">
#             Suspending Dividend
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-special-dividend">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/stocks-etfs-and-funds-paying-a-special-dividend/" href="/stocks-etfs-and-funds-paying-a-special-dividend/">
#             Special Dividend
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-aristocrats">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-aristocrats/" href="/dividend-aristocrats/">
#             Dividend Aristocrats
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-champions">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-champions/" href="/dividend-champions/">
#             Dividend Champions
#            </a>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-etfs-funds-prefs-adrs">
#        <div class="t-flex">
#         <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-etfs-funds-prefs-adrs">
#          ETFs, Funds, Prefs, ADRs
#          <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#         </div>
#        </div>
#        <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-etfs-funds-prefs-adrs">
#         <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#         </div>
#         <section class="t-bg-white t-flex t-flex-col">
#          <div id="mobile-user-data-area">
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-etfs">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-etfs/" href="/dividend-etfs/">
#             Dividend ETFs
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-active-etfs">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/active-etfs/" href="/active-etfs/">
#             Dividend Active ETFs
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-funds">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-funds/" href="/dividend-funds/">
#             Dividend Funds
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-preferred-shares">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/preferred-share-dividend-stocks-etfs-and-funds/" href="/preferred-share-dividend-stocks-etfs-and-funds/">
#             Preferred Shares
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-foreign-adr-dividends">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/foreign-dividend-stocks-etfs-and-funds/" href="/foreign-dividend-stocks-etfs-and-funds/">
#             Foreign (ADR) dividends
#            </a>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-dividend-growers">
#        <div class="t-flex">
#         <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-dividend-growers">
#          Dividend Growers
#          <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#         </div>
#        </div>
#        <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-dividend-growers">
#         <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#         </div>
#         <section class="t-bg-white t-flex t-flex-col">
#          <div id="mobile-user-data-area">
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-aristocrats-25-yrs-s-p500-stocks">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-aristocrats/" href="/dividend-aristocrats/">
#             Dividend Aristocrats (&gt;25 yrs S&amp;P500 stocks)
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-champions-25-yrs">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-champions/" href="/dividend-champions/">
#             Dividend Champions (&gt;25 yrs)
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-achievers-10-yr-nasdaq-stocks">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-achievers/" href="/dividend-achievers/">
#             Dividend Achievers (&gt;10 yr NASDAQ stocks)
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-challengers-5-9-yrs">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-challengers/" href="/dividend-challengers/">
#             Dividend Challengers (5-9 yrs)
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-contenders-10-24-yrs">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-contenders/" href="/dividend-contenders/">
#             Dividend Contenders (10-24 yrs)
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-dividend-kings-50-yrs">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/dividend-kings/" href="/dividend-kings/">
#             Dividend Kings (&gt;50 yrs)
#            </a>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#      </section>
#     </div>
#    </div>
#    <div class="n-nav-item__mobile" id="nav-item-picks">
#     <div class="t-flex">
#      <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-picks">
#       Picks
#       <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#      </div>
#     </div>
#     <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-picks">
#      <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#      </div>
#      <section class="t-bg-white t-flex t-flex-col">
#       <div id="mobile-user-data-area">
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-model-portfolios">
#        <div class="t-flex">
#         <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-model-portfolios">
#          Model Portfolios
#          <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#         </div>
#        </div>
#        <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-model-portfolios">
#         <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#         </div>
#         <section class="t-bg-white t-flex t-flex-col">
#          <div id="mobile-user-data-area">
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-best-high-dividend-stocks">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-high-dividend-stocks/" href="/best-high-dividend-stocks/">
#             Best High Dividend Stocks
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-best-dividend-protection-stocks">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-dividend-protection-stocks/" href="/best-dividend-protection-stocks/">
#             Best Dividend Protection Stocks
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-best-dividend-growth-stocks">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-dividend-growth-stocks/" href="/best-dividend-growth-stocks/">
#             Best Dividend Growth Stocks
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-best-dividend-stocks">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-dividend-stocks/" href="/best-dividend-stocks/">
#             Best Dividend Stocks
#            </a>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-best-monthly-dividend-stocks">
#        <div class="t-flex">
#         <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-monthly-dividend-stocks/" href="/best-monthly-dividend-stocks/">
#          Best Monthly Dividend Stocks
#         </a>
#        </div>
#       </div>
#       <div class="n-nav-item__mobile" id="nav-item-best-sector-dividend-stocks">
#        <div class="t-flex">
#         <div class="n-button_collapse_reference t-cursor-pointer t-flex t-justify-between t-self-center t-w-full" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-collapse-target="collapse-best-sector-dividend-stocks">
#          Best Sector Dividend Stocks
#          <img class="mobile-nav-arrow t-inline t-transition-250 t--rotate-90 t-float-right" src="/packs/media/images/dividend/nav-down-f4211963ea12740606598b688e9ca2fd.svg"/>
#         </div>
#        </div>
#        <div class="t-flex t-flex-col n-button_collapse_target" id="collapse-best-sector-dividend-stocks">
#         <div class="t-fixed t-w-screen t-h-screen t-left-0 t-top-0 t-bg-shadow-overlay t-z-50 background-drop-overlay t-hidden">
#         </div>
#         <section class="t-bg-white t-flex t-flex-col">
#          <div id="mobile-user-data-area">
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-best-financials">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-financial-dividend-stocks/" href="/best-financial-dividend-stocks/">
#             Best Financials
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-best-real-estate">
#           <div class="t-flex">
#            <a class="t-w-full hover:t-no-underline hover:t-text-black" data-analytics-track-click='{"category": "Mobile Navigation", "action": "click"}' data-url-link="/best-real-estate-dividend-stocks/" href="/best-real-estate-dividend-stocks/">
#             Best Real Estate
#            </a>
#           </div>
#          </div>
#          <div class="n-nav-item__mobile" id="nav-item-best-communications">
#           <div class="t-flex">
# ...
#       Best Dividend Capture Stocks
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-stocks/high-dividend-yield-stocks/">
#       High Yield Stocks
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/ex-dividend-dates/">
#       Ex-Dividend Stocks
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-income/">
#       Income Generator
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-stocks/foreign-dividend-stocks/">
#       Foreign Dividend Stocks
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-stock-upgrades-downgrades/">
#       Upgrades/Downgrades
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-portfolios/">
#       Dividend Portfolios
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/tools/compounding-returns-calculator/">
#       Returns Calculator
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-history/">
#       Dividend History Data
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/premium/my-watchlist/">
#       My Watchlist
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/tools/most-watched-stocks/">
#       Most Watched Stocks
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/premium/testimonials/">
#       Testimonials
#      </a>
#     </div>
#     <div class="lg:t-w-1/5 md:t-w-1/3 t-flex t-flex-col t-mb-6 t-pr-6 t-w-1/2">
#      <h6 class="t-text-md t-text-white t-font-bold">
#       Education
#      </h6>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/news/">
#       The Dividend Daily
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-investing-101/">
#       Dividend Investing 101
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/how-to-invest/">
#       Dividend Investing Ideas
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/dividend-education/">
#       Dividend Financial Education
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/how-to-retire/">
#       How to Retire
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/my-money/">
#       How to Manage My Money
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/career/">
#       My Career
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/taxes/">
#       Taxes
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/insurance-and-annuities/">
#       Life Insurance &amp; Annuities
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/how-to-invest/how-to-invest-in-real-estate-crash-course/">
#       Real Estate
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/continuing-education/">
#       University &amp; College
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/investor-resources/">
#       Investor Resources
#      </a>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/lighter-side/">
#       Lighter Side
#      </a>
#     </div>
#     <div class="lg:t-w-1/5 md:t-w-1/3 t-flex t-flex-col t-mb-6 t-pr-6 t-w-1/2">
#      <h6 class="t-text-md t-text-white t-font-bold">
#       Legal
#      </h6>
#      <a class="t-leading-relaxed t-text-tiny t-text-gray-600 hover:t-text-white hover:t-no-underline" href="/legal/">
#       Terms of Use
#      </a>
#      <div class="t-flex t-relative t-mt-5">
#       <div class="social-label t-cursor-pointer t-flex t-float-right t-hidden t-items-center t-leading-loose t-mt-3 t-pt-4 t-text-base t-text-white xl:t-flex">
#        Follow dividend
#       </div>
#       <div class="social-module t-absolute t-flex t-top-0 t-z-10" data-module-type="link">
#        <div class="t-overflow-hidden t-rounded-full t-w-6 t-h-6 t-flex t-flex-wrap t-flex-col t-leading-loose button-group hover:t-flex-inline-block t-will-change-transform t-transition-all t-transition-linear">
#         <button class="t-text-tiny t-text-center t-pull-right t-bg-blue-800 t-rounded-full t-w-6 t-h-6 t-items-center t-justify-center t-cursor-pointer follow t-flex">
#          <a class="t-text-gray-700 t-p-0 t-leading-loose t-flex">
#           <i class="fa fa-user-plus t-text-white">
#           </i>
#          </a>
#         </button>
#         <button class="facebook n-social-share-icon t-cursor-pointer t-flex t-h-6 t-items-center t-justify-center t-mx-1 t-pull-right t-rounded-full t-text-center t-text-tiny t-w-6" data-description="Best High Yield" data-title="Best High Yield" data-url="request.original_url">
#          <a class="t-text-gray-700 t-p-0 t-leading-loose t-flex">
#           <i class="fa fa-facebook t-text-white">
#           </i>
#          </a>
#         </button>
#         <button class="n-social-share-icon t-cursor-pointer t-flex t-h-6 t-items-center t-justify-center t-mx-1 t-pull-right t-rounded-full t-text-center t-text-tiny t-w-6 twitter" data-description="Best High Yield" data-title="Best High Yield" data-url="request.original_url">
#          <a class="t-text-gray-700 t-p-0 t-leading-loose t-flex">
#           <i class="fa fa-twitter t-text-white">
#           </i>
#          </a>
#         </button>
#         <button class="linkedin n-social-share-icon t-cursor-pointer t-flex t-h-6 t-items-center t-justify-center t-mx-1 t-pull-right t-rounded-full t-text-center t-text-tiny t-w-6" data-description="Best High Yield" data-title="Best High Yield" data-url="request.original_url">
#          <a class="t-text-gray-700 t-p-0 t-leading-loose t-flex">
#           <i class="fa fa-linkedin t-text-white">
#           </i>
#          </a>
#         </button>
#        </div>
#       </div>
#       <div class="async-js" data-js-files="[]">
#       </div>
#      </div>
#     </div>
#     <div class="t-w-full t-my-4">
#      <p class="t-text-tiny t-text-gray-600 t-mb-0">
#       All stock quotes on this website should be considered as having a 24-hour delay.
#      </p>
#      <p class="t-text-tiny t-text-gray-600 t-border-t t-border-b t-py-2 t-my-2 t-border-gray-450">
#       *
#       <a class="t-underline t-text-gray-600 hover:t-text-white" href="https://www.dividend.com" target="_blank">
#        Dividend.com
#       </a>
#       does not provide financial advice and does not issue recommendations or offers to buy stock or sell any security.
#      </p>
#      <p class="t-text-tiny t-text-gray-600">
#       Certain financial information included in Dividend.com is proprietary to Mergent, Inc. ("Mergent") Copyright © 2014. Reproduction of such information in any form is prohibited. Because of the possibility of human or mechanical error by Mergent's sources, Mergent or others, Mergent does not guarantee the accuracy, adequacy, completeness, timeliness or availability or for the results obtained from the use of such information.
#      </p>
#     </div>
#    </div>
#    <div class="t-w-full t-bg-gray-900">
#     <div class="t-container t-mx-auto t-flex t-pt-4 t-pb-4 md:t-pb-6 t-items-center t-flex-col md:t-flex-row">
#      <figure class="t-flex-none">
#       <a href="http://mitremedia.com" rel="nofollow" target="_blank">
#        <img src="/packs/media/images/dividend/mitre-logo-d28289c4311782ed6ef77ef9866eecf5.png">
#        </img>
#       </a>
#      </figure>
#      <div class="t-flex-1 t-flex t-justify-center">
#       <h4 class="t-text-gray-600 t-text-lg t-font-bold">
#        <a href="http://mitremedia.com/#partner" rel="nofollow" target="_blank">
#         Advertise With Us
#        </a>
#       </h4>
#      </div>
#      <div class="t-flex-none">
#       <h4 class="t-text-gray-600 t-text-lg t-font-bold">
#        ©
# 2023
#        <a href="http://mitremedia.com" rel="nofollow" target="_blank">
#         Mitre Media
#        </a>
#       </h4>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div class="t-fixed t-w-full t-h-full t-top-0 t-left-0 t-flex t-flex-wrap t-items-center t-justify-center t-z-2000 t-will-change-opacity t-transition-250 t-transition-all t-overflow-auto t-hidden" data-controller="modal" id="exit-interstitial">
#    <div class="modal-overlay t-fixed t-h-full t-w-full t-top-0 t-left-0 t-bg-gray-900 t-opacity-50">
#    </div>
#    <div class="modal-container t-bg-white t-mx-auto t-rounded t-shadow-lg t-z-2050 t-my-10">
#     <div class="modal-content t-py-4 t-text-left t-px-6">
#      <div class="t-flex t-justify-between t-items-center">
#       <h4 class="t-text-2xl t-font-bold t-leading-normal t-text-blue-800 t-text-center">
#        Wait! Rates are rising, is your portfolio ready?
#       </h4>
#       <div class="modal-close t-cursor-pointer t-z-2050" data-action="click-&gt;modal#closeModal">
#        <span class="t-fill-current t-text-gray-500 t-text-md">
#         ×
#        </span>
#       </div>
#      </div>
#      <div class="t-h-px t-bg-gray-400 t-w-full">
#      </div>
#      <div class="t-flex t-my-2">
#       <div class="t-flex t-flex-col t-flex-1">
#        <article class="t-flex-1 t-flex">
#         <figure class="t-relative t-w-40 t-mt-3 t-mr-6 t-flex sm:t-w-32 md:t-w-32">
#          <img alt="Preferred Stocks" class="t-w-40 t-mb-auto t-z-10 sm:t-w-32" href="/how-to-invest/critical-facts-about-preferred-stocks/" onerror="this.src=`/dividend-logo.svg`;this.classList.add(`t-border`);this.classList.add(`t-bg-white`);this.classList.add(`t-border-gray-300`);this.classList.add(`t-border-solid`);" src="https://images.ctfassets.net/bpdxa94spjot/5hXloVeKeTJBCMsnypajL9/2fc0bb6552d248266c23714b1fe60acc/shutterstock_351904781.jpg?&amp;h=232&amp;w=174"/>
#         </figure>
#         <div class="t-flex-1 t-flex-col">
#          <p class="t-text-2xs t-uppercase t-text-blue-700 t-font-semibold t-mb-0">
#           Dividend Investing Ideas Center
#          </p>
#          <h2 class="t-mb-0 t-leading-zero">
#           <a class="t-text-lg t-font-semibold t-leading-tight" href="/how-to-invest/critical-facts-about-preferred-stocks/">
#            Critical Facts You Need to Know About Preferred Stocks
#           </a>
#          </h2>
#          <div class="t-flex t-flex-row">
#           <a class="t-text-tiny t-text-gray-600" href="/authors/michael-mcdonald/">
#            Michael McDonald
#           </a>
#           <time class="t-text-tiny t-text-gray-600 t-ml-3">
#           </time>
#          </div>
#          <p class="t-text-tiny t-my-3">
#           Have you ever wished for the safety of bonds, but the return potential...
#          </p>
#         </div>
#        </article>
#        <div class="t-h-px t-bg-gray-400 t-w-full t-my-4">
#        </div>
#        <article class="t-flex-1 t-flex">
#         <figure class="t-relative t-w-40 t-mt-3 t-mr-6 t-flex sm:t-w-32 md:t-w-32">
#          <img alt="Retirement" class="t-w-40 t-mb-auto t-z-10 sm:t-w-32" href="/insurance-and-annuities/earn-more-dividend-stocks-annuities-retirement/" onerror="this.src=`/dividend-logo.svg`;this.classList.add(`t-border`);this.classList.add(`t-bg-white`);this.classList.add(`t-border-gray-300`);this.classList.add(`t-border-solid`);" src="https://images.ctfassets.net/bpdxa94spjot/4AhFbzFWEsc0D3ktLm9onu/cbfa294d1ca48336d9b07af558cbd13d/shutterstock_42856108.jpg?w=174&amp;h=232"/>
#         </figure>
#         <div class="t-flex-1 t-flex-col">
#          <p class="t-text-2xs t-uppercase t-text-blue-700 t-font-semibold t-mb-0">
#           Dividend Investing Ideas Center
#          </p>
#          <h2 class="t-mb-0 t-leading-zero">
#           <a class="t-text-lg t-font-semibold t-leading-tight" href="/insurance-and-annuities/earn-more-dividend-stocks-annuities-retirement/">
#            Earn More With Dividend Stocks Than With Annuities for Your Retirement
#           </a>
#          </h2>
#          <div class="t-flex t-flex-row">
#           <a class="t-text-tiny t-text-gray-600" href="/authors/asif-imtiaz/">
#            Asif Imtiaz
#           </a>
#           <time class="t-text-tiny t-text-gray-600 t-ml-3">
#           </time>
#          </div>
#          <p class="t-text-tiny t-my-3">
#           If you are reaching retirement age, there is a good chance that you...
#          </p>
#         </div>
#        </article>
#        <div class="t-h-px t-bg-gray-400 t-w-full t-my-4">
#        </div>
#        <article class="t-flex-1 t-flex">
#         <figure class="t-relative t-w-40 t-mt-3 t-mr-6 t-flex sm:t-w-32 md:t-w-32">
#          <img alt="retirement" class="t-w-40 t-mb-auto t-z-10 sm:t-w-32" href="/my-money/an-introduction-to-certificates-of-deposit-cds/" onerror="this.src=`/dividend-logo.svg`;this.classList.add(`t-border`);this.classList.add(`t-bg-white`);this.classList.add(`t-border-gray-300`);this.classList.add(`t-border-solid`);" src="https://images.ctfassets.net/rh81el08iwni/1h1UJy6McNsvPrKCahOc59/9c7e488c8e16512d8b496b38cbef99a3/stock-market-chart-xs.jpg?w=174&amp;h=232"/>
#         </figure>
#         <div class="t-flex-1 t-flex-col">
#          <p class="t-text-2xs t-uppercase t-text-blue-700 t-font-semibold t-mb-0">
#           Dividend Investing Ideas Center
#          </p>
#          <h2 class="t-mb-0 t-leading-zero">
#           <a class="t-text-lg t-font-semibold t-leading-tight" href="/my-money/an-introduction-to-certificates-of-deposit-cds/">
#            Earn More With Dividend Stocks Than With Annuities for Your Retirement
#           </a>
#          </h2>
#          <div class="t-flex t-flex-row">
#           <a class="t-text-tiny t-text-gray-600" href="/authors/asif-imtiaz/">
#            Asif Imtiaz
#           </a>
#           <time class="t-text-tiny t-text-gray-600 t-ml-3">
#           </time>
#          </div>
#          <p class="t-text-tiny t-my-3">
#           If you are reaching retirement age, there is a good chance that you...
#          </p>
#         </div>
#        </article>
#        <div class="t-h-px t-bg-gray-400 t-w-full t-my-4">
#        </div>
#        <div class="async-js" data-js-files="[]">
#        </div>
#       </div>
#       <div class="t-flex t-flex-col t-flex-1">
#        <div class="mitread--adunit__oa ad-type-O-02-A t-flex t-flex-end" id="19e753afdb74450c34717438a04a0b65-c">
#         <div data-ad-unit-ad-unit="O-02-A" data-ad-unit-id="19e753afdb74450c34717438a04a0b65" data-ad-unit-is-native="false" data-ad-unit-kfp="true" data-ad-unit-name="Div/Theme/BestList/O-02-A" data-ad-unit-only-if="exitInterstitialHasNotBeenServed" data-ad-unit-type="oa" data-controller="ad-unit" id="19e753afdb74450c34717438a04a0b65">
#         </div>
#         <div data-ad-position-id="/2143012/Div/Theme/BestList/O-02-A" data-controller="ad-position">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="t-flex t-mt-1 t-justify-center">
#      </div>
#      <div class="t-flex t-justify-end t-pt-2">
#       <button class="modal-close close t-px-4 t-h-8 t-bg-white t-border t-rounded t-text-gray-800 hover:t-bg-gray-200" data-action="click-&gt;modal#closeModal">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="async-js" data-js-files="[]">
#   </div>
#   <div class="async-js" data-js-files="[]">
#   </div>
#  </body>
# </html>
